# %% [markdown]
# <a href="https://colab.research.google.com/github/ai-technipreneurs/python_course_colab_notebooks/blob/main/07_Lecture07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <a href="https://aims-senegal.org/" ><img src="images/logoaimssn.jpeg" style="float:left; max-width: 650px; display: inline" alt="AIMS-SN"/> </a>
#     </center>
#
#
#
# <center>
#
# <a href="https://acas-yde.org/" ><img src="images/logo-ACAS.jpg" style="float:right; max-width: 250px; display: inline" alt="ACAS"/></a>
#
# </center>

# %% [markdown]
# ****
#
# # <center> <b> <span style="color:orange;"> Python Proficiency for Scientific Computing and Data Science (PyPro-SCiDaS)  </span> </b></center>
#
# ### <center> <b> <span style="color:green;">An Initiation to Programming using Python (Init2Py) </span> </b></center>

# %% [markdown]
# ****
#
# # <center> <b> <span style="color:blue;"> Lecture 7: Matplotlib </span> </b></center>
#
# <!--NAVIGATION-->
# <  [6.Numpy](06.Lecture06.ipynb)| [ToC](Index.ipynb) |
#
# ****

# %% [markdown]
# Adapted from [Matplotlib-guide](http://scipy-lectures.org/intro/matplotlib/) and [Matplotlib-official](https://matplotlib.org/).
#
# * * * *
#
# <img src="matplotlib.png" alt="Vlad's Home Directory" />
#
#
#
# Matplotlib is a Python library for data visualization (2D/3D-graphics, animation etc.). It provides publication-quality figures in many formats. We will explore matplotlib in interactive mode covering most common cases in this tutorial.

# %% [markdown]
# ### <left> <b> <span style="color:brown;"> Objective: </span> </b></left>
#
# This lecture aims to introduce the core concepts of `Matplotlib`, a powerful library for creating visualizations in Python. We will explore how to generate various types of plots, customize visual elements, and effectively communicate data insights through charts and graphs. By understanding these tools, you'll gain the ability to create informative and aesthetically pleasing visualizations, which are essential for data analysis, reporting, and scientific communication using `Matplotlib`.
# ****

# %%
# mandatory/necessary imports

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # for 3D plotting

# %% [markdown]
# **pyplot** provides a convenient interface to the matplotlib object-oriented plotting library. Let's look at the line
#
#                                 import matplotlib.pyplot as plt
#
# of the previous code.
#
# This is the preferred format to import the main Matplotlib submodule for plotting,
# ``pyplot``. It's the best practice and in order to avoid pollution of the global namespace.
# The same import style is used in the official documentation, so we want to be
# consistent with that.
#
# Important commands are explained with interactive examples.

# %%
# check version
matplotlib.__version__
# Out:
# '3.9.2'

# %% [markdown]
# Let's now see a simple plotting and understand the ingredients that goes into customizing our plot as per our will and wish.

# %% [markdown]
# ## **Simple curve plot**

# %%
# get 10 linearly spaced points in the interval [0, 5)
x = np.linspace(0, 5, 10)
y = x ** 2

# create a figure/canvas of desired size
plt.figure(figsize=(8, 6))

# plot values; with a color `red`
plt.plot(x, y, 'r')

# give labels to the axes
plt.xlabel('x')
plt.ylabel('y')

# give a title to the plot
plt.title(r"Plot of $y=x^2$")
plt.show()

# %% [markdown]
# ### **Cosine & Sine Plot**
#
# Starting with default settings, we would like to draw a `cosine` and `sine` functions on the same plot. Then, we will make it look prettier by customizing the default settings.

# %%
# 256 linearly spaced values between -pi and +pi
# both endpoints would be included; check (X[0], X[-1])
X = np.linspace(-np.pi, np.pi, 256)

# compute cosine and sin values
C, S = np.cos(X), np.sin(X)

# plot both curves
plt.plot(X, C)
plt.plot(X, S)

# show the plot
plt.show()

# %% [markdown]
# #### The above plot doesn't seem too appealing. So, let's customizing the default settings a bit.
#
# *Matplotlib* allows the aspect ratio, DPI and figure size to be specified when the Figure object is created, using the `figsize` and `dpi` keyword arguments. `figsize` is a tuple of the `width` and `height` of the figure in inches, and `dpi` is the dots-per-inch (pixel per inch). To create an 800x600 pixel, 100 dots-per-inch figure, we can do:

# %%
# Create a new figure of size 800x600, using 100 dots per inch
plt.figure(figsize=(8, 6), dpi=100)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

# Now, plot `cosine` using `blue` color with a continuous line of width 1 (pixel)
plt.plot(X, C, color="red", linewidth=1.0, linestyle="-")

# And plot `sine` using `green` color with a continuous line of width 1 (pixel)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits to [-4, +4]
plt.xlim(-4.0, 4.0)

# Set y limits to [-1, +1]
plt.ylim(-1.0, 1.0)

# optionally, save the figure as a pdf using 72 dots per inch
plt.savefig("./sine_cosine.pdf", format='pdf', dpi=72)

# show grid
plt.grid(True)

# Show the plot on the screen
plt.show()

# %% [markdown]
# --------
#
# ##  Setting axes limits
#
# Instead of hard-coding the `xlim` and `ylim` values, we can take these values from the array itself and then set the limits accordingly.
# We can also change the `linewidth` and `color` kwargs as per our wish.

# %%
# set figure size and dpi (dots per inch)
plt.figure(figsize=(10, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

# customize color and line width
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

# set lower & upper bound by taking min & max value respectively
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)
# adding legend on the upper left side 
plt.legend(loc='upper left',frameon=False)
# optionally, save the figure as a pdf using 72 dots per inch
plt.savefig("./sine_cosine.pdf", format='pdf', dpi=80)

# show it on screen
plt.show()

# %% [markdown]
# ## Setting axes ticks

# %%
# set figure size and dpi (dots per inch)
plt.figure(figsize=(10, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

# customize color and line width
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# set lower & upper bound by taking min & max value respectively
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# provide five tick values for x and 3 for y
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# optionally, save the figure as a pdf using 72 dots per inch
plt.savefig("./sine_cosine.pdf", format='pdf', dpi=80)

# show it on screen
plt.show()

# %% [markdown]
# ## Setting axes tick labels
#
# We fixed the aexs ticks but their label is not very explicit. We could guess that 3.142 is π but it would be better to make it explicit. When we set tick values, we can also provide a corresponding label in the second argument list. Note that we'll use latex to allow for nice rendering of the label.

# %%
# set figure size and dpi (dots per inch)
plt.figure(figsize=(10, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

# customize color and line width
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# set lower & upper bound by taking min & max value respectively
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# provide five tick values for x and 3 for y
# and pass the corresponding label as a second argument.
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
           [r'$-1$', r'$0$', r'$+1$'])

# optionally, save the figure as a pdf using 72 dots per inch
plt.savefig("./sine_cosine.pdf", format='pdf', dpi=80)

# show it on screen
plt.show()

# %% [markdown]
# ## Adding legends

# %%
# set figure size and dpi (dots per inch)
plt.figure(figsize=(10, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

# customize color and line width
# `label` is essential for `plt.legend` to work
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

# set lower & upper bound by taking min & max value respectively
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# provide five tick values for x and 3 for y
# and pass the corresponding label as a second argument.
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],
           [r'$-1$', r'$0$', r'$+1$'])

# show legend on the upper left side of the axes
plt.legend(loc='upper left', frameon=False)

# optionally, save the figure as a pdf using 72 dots per inch
plt.savefig("./sine_cosine.pdf", format='pdf', dpi=80)

# show it on screen
plt.show()

# %% [markdown]
# ----------
#
# ### **Figure and Subplots**
#
# **Figure**
#
# A figure is the windows in the GUI that has "Figure #" as title. Figures are numbered starting from 1 as opposed to the normal Python way starting from 0. There are several parameters that determine how the figure looks like.

# %% [markdown]
# | Argument | Default       |Description |
# |----------|:-------------:|------:|
# | num      | 1             | number of figure |
# | figsize  |figure.figsize | figure size in in inches (width, height)|
# | dpi      |figure.dpi |   resolution in dots per inch|
# |facecolor |figure.facecolor|color of the drawing background|
# |edgecolor |figure.edgecolor|color of edge around the drawing background|
# |frameon   |True            | draw figure frame or not |

# %% [markdown]
# **Subplot**
#
# With subplot you can arrange plots in a regular grid. You need to specify the number of rows and columns and the number of the plot.

# %% [markdown]
# The following plot shows how to use the *figure title*, *axis labels*, and *legends* in a subplot:

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

fig, axes = plt.subplots(1, 2, figsize=(8,4), dpi=100)

# plot subplot 1
axes[0].plot(x, x**2, color="green", label="y = x**2")
axes[0].plot(x, x**3, color="red", label="y = x**3")
axes[0].legend(loc=2); # upper left corner
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('Plot of y=x^2 and y=x^3')

# plot subplot 2
axes[1].plot(x, x**2, color="violet", label="y = x**2")
axes[1].plot(x, x**3, color="blue", label="y = x**3")
axes[1].legend(loc=2); # upper left corner
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
axes[1].set_title('Plot of y=x^2 and y=x^3')

# `fig.tight_layout()` automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content
# comment this out to see the difference
fig.tight_layout()

plt.show()

# %% [markdown]
# ## **Formatting text: LaTeX, fontsize, font family**
#
# Matplotlib has great support for $LaTeX$. All we need to do is to use dollar signs encapsulate LaTeX in any text (legend, title, label, etc.). For example, `"$y=x^3$"`.
#
# But here we might run into a slightly subtle problem with $LaTeX$ code and Python text strings. In $LaTeX$, we frequently use the backslash in commands, for example `\alpha` to produce the symbol α. But the backslash already has a meaning in Python strings (the escape code character). To avoid Python messing up our latex code, we need to use "raw" text strings. Raw text strings are prepended with an `'r'`, like `r"\alpha"` or `r'\alpha'` instead of `"\alpha"` or `'\alpha'`:

# %%
fig, ax = plt.subplots(figsize=(8,4), dpi=100)

ax.plot(x, x**2, label=r"$y = \alpha^2$")
ax.plot(x, x**3, label=r"$y = \alpha^3$")
ax.legend(loc=2) # upper left corner
ax.set_xlabel(r'$\alpha$', fontsize=18)
ax.set_ylabel(r'$y$', fontsize=18)
ax.set_title(r'Plot of y=$\alpha^{2}$ and y=$\alpha^{3}$')
plt.show()

# %% [markdown]
# ## **Line and marker styles**
#
# To change the line width, we can use the `linewidth` or `lw` keyword argument. The line style can be selected using the `linestyle` or `ls` keyword arguments:

# %%
fig, ax = plt.subplots(figsize=(12,6))

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="green", lw=2, ls='--', marker='+')
ax.plot(x, x+10, color="green", lw=2, ls='--', marker='o')
ax.plot(x, x+11, color="green", lw=2, ls='--', marker='s')
ax.plot(x, x+12, color="green", lw=2, ls='--', marker='1')

plt.show()

# %% [markdown]
# ## **Logarithmic scale**
# It is also possible to set a logarithmic scale for one or both axes. This functionality is in fact only one application of a more general transformation system in Matplotlib. Each of the axes' scales are set seperately using `set_xscale` and `set_yscale` methods which accept one parameter (with the value `"log"` in this case):

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# plot normal scale
axes[0].plot(x, np.exp(x), color="red")
axes[0].plot(x, x**2, color="green")
axes[0].set_title("Normal scale")
axes[0].grid()  # show grid

# plot `log` scale
axes[1].plot(x, np.exp(x), color="red")
axes[1].plot(x, x**2, color="green")
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
axes[1].grid()  # show grid

fig.tight_layout()
plt.show()

# %% [markdown]
# ## **Histogram plot**

# %%
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# plot default histogram
axes[0].hist(n, bins=50, color="blue")
axes[0].set_title("Default histogram")
axes[0].set_xlim((np.min(n), np.max(n)))

# plot cumulative histogram
axes[1].hist(n, cumulative=True, bins=50, color="green")
axes[1].set_title("Cumulative detailed histogram")
axes[1].set_xlim((np.min(n), np.max(n)))

fig.tight_layout()
plt.show()

# %% [markdown]
# ## **Common types of plots**
#
# - **Scatter plot**
#  A simple scatter plot of random values drawn from the standard Gaussian distribution.

# %%
# set figure size and dpi (dots per inch)
plt.figure(figsize=(10, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

# color is given by the angle between X & Y
T = np.arctan2(Y,X)

plt.axes([0.025, 0.025, 0.95, 0.95])

# The alpha blending value, between 0 (transparent) and 1 (opaque).
# s - marker size
# c - color
plt.scatter(X,Y)#, s=75, c=T, alpha=.5)

plt.xlim(-2.0, 2.0), plt.xticks([])
plt.ylim(-2.0, 2.0), plt.yticks([])
plt.show()

# %% [markdown]
# --------
#
# - **Contour plot**
#   A contour plot represents a 3-dimensional surface by plotting constant z slices, called contours, on a 2-dimensional grid.

# %%
# set figure size and dpi (dots per inch)
plt.figure(figsize=(10, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)


def f(x,y):
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x, y)

plt.axes([0.025, 0.025, 0.95, 0.95])

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap=plt.cm.hot)
C = plt.contour(X, Y, f(X,Y), 8, colors='black')
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# --------
#
# - **3D plot**
#   Represent a 3-dimensional surface.  To use 3D graphics in matplotlib, we first need to create an axes instance of the class `Axes3D`. 3D axes can be added to a matplotlib figure canvas in exactly the same way as 2D axes, but a conventient way to create a 3D axis instance is to use the projection='3d' keyword argument to the add_axes or add_subplot functions.
#
#   Note: You can't rotate the plot in jupyter notebook. Plot it as a standalone module to zoom around and visualize it by rotating.

# %%
# create figure and set figure size and dpi (dots per inch)
fig = plt.figure(figsize=(10, 6), dpi=80)
ax = Axes3D(fig)

# inputs
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)

X, Y = np.meshgrid(X, Y)

# 3D surface
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)

# set z axis limit
ax.set_zlim(-3, 3)

plt.show()

# %%
# create figure and set figure size and dpi (dots per inch)
fig = plt.figure(figsize=(10, 6), dpi=80)
ax = fig.add_subplot(1, 1, 1, projection='3d')  # Correct way to add a 3D subplot

# inputs
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)

# 3D surface
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# Plot contour lines
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap='hot')

# set z axis limit
ax.set_zlim(-3, 3)

# Show plot
plt.show()

# %% [markdown]
# --------
#
# - **3D Surface Plot**

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p)*np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %%
fig = plt.figure(figsize=(25, 10))

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

plt.show()

# %% [markdown]
# --------
#
# - **3D Wireframe Plot**

# %%
fig = plt.figure(figsize=(25, 10))

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 1, 1, projection='3d')

# create and plot a wireframe
p = ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4)

plt.show()

# %% [markdown]
# --------
#
# - **Coutour plots with axis level projections**

# %%
fig = plt.figure(figsize=(18, 8))

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 1, 1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=plt.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);

plt.show()

# %% [markdown]
# **Changing viewing angle**
#  - We can change the perspective of a 3D plot using the `view_init` function, which takes two arguments: the elevation and the azimuth angles (unit degrees)

# %%
fig = plt.figure(figsize=(8, 8))

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(2, 1, 1, projection='3d')
ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
ax.view_init(30, 45)

# `ax` is a 3D-aware axis instance, because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(2,1,2, projection='3d')
ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
ax.view_init(70, 30)

fig.tight_layout()

# %%
Exercise 1:
Create a simple line plot for y = x for x values ranging from 0 to 10.

# %%
x=np.linspace(0,5,10)
y=x
plt.plot(x,y)
plt.title("linear equation line")
plt.show()

# %%
Exercise 2:
Plot y = x^2 using Matplotlib for x values between -10 and 10.

# %%
x=np.linspace(-10,10,100)
y=x**2
plt.plot(x,y)
plt.show()

# %%
### Exercise 3:
Create a scatter plot with 50 random points where x and y values are between 0 and 10.

# %%
n=50
x=10*np.random.random(n)
y=10*np.random.random(n)
plt.scatter(x,y)

# %%
Plot a sine wave using Matplotlib for x values between 0 and 2π.

# %%
x = np.linspace(0, 2*np.pi, 200)
S = np.sin(x)
plt.plot(x,S)
plt.title("Sin(x)")
plt.grid(True)
plt.show()

# %%
### Exercise 5:
Create a bar chart for the following data: `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
categories=['A','B','C','D']
values=[3,7,5,9]
plt.bar(categories,values)
plt.ylabel("categories")
plt.xlabel("values")
plt.title("Bar chart(categories)")
plt.show()

# %%
### Exercise 6:
Create a histogram of 1000 random numbers generated from a normal distribution.

# %%
#N=1000
N= np.random.random(1000)
#y= np.random.random(N)
plt.hist(N, bins=30, edgecolor="black")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Exercise 7.
Plot two line plots on the same graph: `y1 = x^2` and `y2 = x^3` for `x` ranging from 0 to 10.

# %%
x=np.linspace(0,10,10)
y1= x**2
y2= x**3
plt.plot(y1,y2,color="red")
plt.grid(True)
plt.title("y1 and y2 plot")
plt.show()

# %%
#Exercise 8.
x=np.linspace(0,10,10)
y1= x**2
y2= x**3
plt.plot(x,y1,label=" y1 = x**2",color="blue")
plt.plot(x,y2,label=" y2 = x**3",color="red")
plt.xlabel("y1 values")
plt.ylabel("y2 values")
plt.legend()
plt.grid(True)
plt.title("y1 and y2 plot")
plt.show()

# %%
#Exercise 9.
Create a subplot with 2 rows and 1 column. Plot `y1 = x^2` in the first subplot and `y2 = x^3` in the second.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

# First subplot: y = x^2
ax1.plot(x, y1, color="blue", label="y = x^2")
ax1.set_title("Plot for y = x^2")
ax1.set_ylabel("y1 values")
ax1.grid(True)
ax1.legend()

# Second subplot: y = x^3
ax2.plot(x, y2, color="yellow", label="y = x^3")  # Use a string for the label
ax2.set_title("Plot for y = x^3")
ax2.set_xlabel("x values")
ax2.set_ylabel("y2 values")
ax2.grid(True)
ax2.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
#Exercise8.
Use a different color and linestyle for each line in a plot of three functions: `y1 = x`, `y2 = x^2`, and `y3 = x^3`.

# %%
y1=x
y2= x**2
y3= x**3
plt.plot(x,y1,label=" y1 = x",color="blue")
plt.plot(x,y2,label=" y2 = x**2",color="green")
plt.plot(x,y3,label=" y2 = x**3",color="red")
plt.xlabel("y1 values")
plt.ylabel("y2 values")
plt.legend()
plt.grid(True)
plt.title("y1, y2 and y3 plot")
plt.show()

# %%
Exercise 10.
Create a pie chart with 5 segments labeled A, B, C, D, and E, with values `[25, 35, 20, 15, 5]`.

# %%
segements=['A','B','C','D','E']
Values=[25, 35, 20, 15, 5]
plt.pie(Values, labels=segements, autopct='%1.1f%%', startangle=90)
plt.title("Pie chart")
plt.axis('equal')
plt.show()

# %%
### Exercise 12:
Create a horizontal bar chart with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
plt.barh(values, categories, color='red')
plt.title("Horizontal bar chart")
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
plt.barh(values, categories, color='red')
plt.figure(figsize=(10, 6))

plt.title("Horizontal bar chart")
plt.show()

# %%
x=np.linspace(0,10,10)
y2= x**3
y1=x**2
plt.plot(y1,y2,color="red")
plt.grid(True)
plt.title("y1 and y2 plot")
plt.figure(figsize=(10, 6))
plt.show()

# %%
### Exercise 14:
Plot a filled area under the curve of `y = x^2` for `x` ranging from 0 to 10.

# %%
x = np.linspace(0, 10, 100)
y = x ** 2  # Calculate y = x^2
plt.figure(figsize=(10, 6))

# Plot the filled area under the curve
plt.fill_between(x, y, color='skyblue')

# Plot the curve
plt.plot(x, y, label='y = x^2', color='blue')
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Filled Area Under the Curve of y = x^2')
plt.legend()
plt.grid(True)
plt.show()

# %%
### Exercise 15:
Change the style of the plot to `ggplot` and replot the sine wave from Exercise 4.

# %%
x = np.linspace(0, 2*np.pi, 200)
S = np.sin(x)
# Use the ggplot style
plt.style.use('ggplot')

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x, S, label='y = sin(x)', color='blue')

# Add labels and title
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Sine Wave Plot with ggplot Style')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %%
### Exercise 16:
Create a stacked bar chart for the following data: `Group A = [3, 5, 7]`, `Group B = [2, 6, 4]`, and `categories = ['X', 'Y', 'Z']`.

# %%
x = np.arange(len(categories))
categories = ['X', 'Y', 'Z']
Group_A = [3, 5, 7]
Group_B = [2, 6, 4]
plt.bar(x, Group_A, width=0.5, label='Group A', color='skyblue')
plt.bar(x, Group_B, width=0.5, bottom=Group_A, label='Group B', color='salmon')
plt.title("Bar chart")
plt.xticks(x, categories)  # Set the category labels on the x-axis
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %%
x = np.linspace(0, 10, 100)

# Create the figure and a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot y1 = x 
axs[0, 0].plot(x, x, color='blue')
axs[0, 0].set_title('y = x')
axs[0, 0].set_xlabel('x values')
axs[0, 0].set_ylabel('y values')
axs[0, 0].grid(True)

# Plot y2 = x^2 
axs[0, 1].plot(x, x**2, color='orange')
axs[0, 1].set_title('y = x^2')
axs[0, 1].set_xlabel('x values')
axs[0, 1].set_ylabel('y values')
axs[0, 1].grid(True)

# Plot y3 = x^3 
axs[1, 0].plot(x, x**3, color='green')
axs[1, 0].set_title('y = x^3')
axs[1, 0].set_xlabel('x values')
axs[1, 0].set_ylabel('y values')
axs[1, 0].grid(True)

# Plot y4 = x^4 
axs[1, 1].plot(x, x**4, color='red')
axs[1, 1].set_title('y = x^4')
axs[1, 1].set_xlabel('x values')
axs[1, 1].set_ylabel('y values')
axs[1, 1].grid(True)
plt.tight_layout()
plt.show()

# %%
### Exercise 18:
Create a heatmap using a 2D array of random values with shape (5, 5).

# %%
data = np.random.rand(5, 5)

# Create the heatmap
plt.figure(figsize=(8, 6))
plt.imshow(data, cmap='viridis', interpolation='nearest')

# Add color bar
plt.colorbar(label='Value')

# Add title and labels
plt.title('Heatmap of Random Values')
plt.xlabel('Columns')
plt.ylabel('Rows')

# Display the heatmap
plt.show()

# %%
### Exercise 19:
Add error bars to a bar plot with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`, assuming the error is 1 for each value.

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
error = 1 
# Create the bar plot with error bars
plt.bar(values,categories, yerr=error, capsize=5, color='skyblue', alpha=0.7)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot with Error Bars')
plt.grid(True)
plt.show()

# %%
### Exercise 20:
Plot a sine wave using a dashed line and a cosine wave using a solid line on the same plot.

# %%
X = np.linspace(-np.pi, np.pi, 256)

# compute cosine and sin values
C, S = np.cos(X), np.sin(X)

# plot both curves
plt.plot(X, S, label='Sine Wave (y = sin(x))', linestyle='--', color='blue')
plt.plot(X, C, label='Cosine Wave (y = cos(x))', linestyle='-', color='orange')
# show the plot
plt.show()

# %%
### Exercise 21:
Plot a contour plot for the function `z = sin(x) + cos(y)` over a grid of `x` and `y` values ranging from -5 to 5.

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
#  the function of z
Z = np.sin(X) + np.cos(Y)

# Create the contour plot
plt.figure(figsize=(10, 6))
contour = plt.contour(X, Y, Z, levels=20, cmap='viridis')
# Add labels and title
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Contour Plot of z = sin(x) + cos(y)')
plt.grid(True)
plt.show()

# %%
### Exercise 22:
Create a box plot for a dataset generated with 100 random numbers from a normal distribution.

# %%
data = np.random.normal(0, 1, 100)

# Create the box plot
plt.figure(figsize=(8, 6))
plt.boxplot(data)
plt.title('Box Plot of Random Numbers from Normal Distribution')
plt.ylabel('Value')
plt.xticks([1], ['Normal Distribution'])  # Label for the box plot

plt.grid(True)
plt.show()

# %% [markdown]
# ****
#
# <!--NAVIGATION-->
# <  [6.Numpy](06.Lecture06.ipynb)| [ToC](Index.ipynb) |
#
# ****

# %%
### Exercise 23:
Create a scatter plot with a color map applied to the points, where the color represents the value of the points.

# %%
import plotly.graph_objects as go
import numpy as np

# Sample data
x = np.random.rand(50)
y = np.random.rand(50)
values = np.random.rand(50)  # The values to color by

# Create scatter plot with colormap
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers', marker=dict(size=15, color=values,  colorscale='Viridis',  showscale=True )))

# Customize the layout
fig.update_layout(
    title="Scatter Plot with Colormap",
    xaxis_title="X-axis",
    yaxis_title="Y-axis"
)

fig.show()

# %%
Exercise 24
Use Matplotlib to display an image from a file.

# %%
import matplotlib.image as mpimg

# Load the image from a file
image_path = "C:\\Users\\USER\\Downloads\\AIMS Rwanda.png"  # Replace with the path to your image
image = mpimg.imread(image_path)

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Hide the axes for a cleaner display
plt.title("Displayed Image")
plt.show()

# %%
Exercise 25
Create a plot with logarithmic scaling on both axes.

# %%
# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

z = x**2 + y**2

# Create a figure and 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_title(r'$z = x^2 + y^2$')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

plt.show()
